# %%
import pandas as pd
df=pd.read_csv('FyntraCustomerData.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
import seaborn as sb
sb.jointplot(df['Time_on_Website'],df['Yearly_Amount_Spent'])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sb
sb.jointplot(df['Time_on_App'],df['Yearly_Amount_Spent'],color='g')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.pairplot(df)

# %%
sb.lmplot('Length_of_Membership','Yearly_Amount_Spent',data=df)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
x=df.iloc[:,3:7].values
y=df.iloc[:,7].values
from sklearn.preprocessing import MaxAbsScaler
ms=MaxAbsScaler()
x=ms.fit_transform(x)
from sklearn.model_selection import train_test_split
a,b,c,d=train_test_split(x,y,test_size=0.30,random_state=85)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(a,c)
lr_output=lr.predict(b)
lr_output
# Out:
# array([467.00047161, 543.20886806, 282.72323428, 538.1018527 ,
#        512.59731486, 478.41303679, 447.55173404, 572.72885095,
#        443.61886133, 580.93780221, 430.32438136, 481.26540398,
#        507.16241439, 553.48907215, 562.31204044, 610.37546447,
#        483.82099189, 504.85290856, 485.08551906, 313.43147427,
#        471.23745389, 493.01940551, 472.79128908, 402.73049548,
#        488.5184849 , 513.10181535, 450.39171597, 379.36013727,
#        423.50598007, 576.31982125, 370.25779587, 486.58885917,
#        499.81514519, 507.86850981, 535.66149122, 408.11730269,
#        540.6113338 , 503.79202984, 416.29905314, 386.62821877,
#        520.98715366, 445.72244871, 498.63913175, 552.9712851 ,
#        525.49555012, 607.31412579, 458.35405174, 525.74064716,
#        424.7215992 , 497.76517111, 449.15174021, 462.60591241,
#        576.24771398, 530.75566906, 542.48025015, 498.34094085,
#        615.06674117, 475.60109252, 568.88764354, 513.19550545,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(lr_output,d)
# Out:
# 0.9785924151347338

# %%
sb.scatterplot(lr_output,d)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(lr_output,d)
# Out:
# 111.78111141320949
